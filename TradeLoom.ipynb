# %%
# !pip install pandas numpy matplotlib pandas-datareader
# Out:
# ...
#   Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.10.7-cp311-cp311-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.60.1-cp311-cp311-win_amd64.whl.metadata (114 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached lxml-6.0.2-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# ...
# Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
# !pip install yfinance
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      ----------- ---------------------------- 262.1/949.2 kB ? eta -:--:--
#      ----------- ---------------------------- 262.1/949.2 kB ? eta -:--:--
#      ------------------- ---------------- 524.3/949.2 kB 524.3 kB/s eta 0:00:01
#      ------------------- ---------------- 524.3/949.2 kB 524.3 kB/s eta 0:00:01
# ...

# %%
import yfinance as yf
import datetime as dt

stock = "BTC-USD"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2025, 10, 27)

df = yf.download(stock, start, end)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25952\1764443878.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock, start, end)
# [*********************100%***********************]  1 of 1 completed

# %%
df.tail()
# Out:
# Price               Close           High            Low           Open  \
# Ticker            BTC-USD        BTC-USD        BTC-USD        BTC-USD
# Date
# 2025-10-22  107688.585938  109115.132812  106778.000000  108491.531250
# 2025-10-23  110069.726562  111288.593750  107548.429688  107679.437500
# 2025-10-24  111033.921875  111842.531250  109770.148438  110069.351562
# 2025-10-25  111641.726562  111947.703125  110704.406250  111032.617188
# 2025-10-26  114472.445312  115260.906250  111268.484375  111639.054688
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2025-10-22  80807013218
# 2025-10-23  54944076060
# 2025-10-24  48160816980
# 2025-10-25  24707667305
# 2025-10-26  41708524143

# %%
df.shape
# Out:
# (4058, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4058 entries, 2014-09-17 to 2025-10-26
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Close, BTC-USD)   4058 non-null   float64
#  1   (High, BTC-USD)    4058 non-null   float64
#  2   (Low, BTC-USD)     4058 non-null   float64
#  3   (Open, BTC-USD)    4058 non-null   float64
#  4   (Volume, BTC-USD)  4058 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 190.2 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   BTC-USD    0
# High    BTC-USD    0
# Low     BTC-USD    0
# Open    BTC-USD    0
# Volume  BTC-USD    0
# dtype: int64

# %%
df.describe()
# Out:
# Price           Close           High            Low           Open  \
# Ticker        BTC-USD        BTC-USD        BTC-USD        BTC-USD
# count     4058.000000    4058.000000    4058.000000    4058.000000
# mean     25757.189283   26254.400358   25181.622983   25730.180797
# std      30701.455069   31205.551747   30118.569823   30673.293278
# min        178.102997     211.731003     171.509995     176.897003
# 25%       2555.352478    2624.884949    2484.554932    2550.030029
# 50%      10400.291992   10672.213867   10186.104492   10397.971680
# 75%      40419.930664   41453.677734   39367.844727   40376.887695
# max     124752.531250  126198.070312  123196.046875  124752.140625
#
# Price         Volume
# Ticker       BTC-USD
# count   4.058000e+03
# mean    2.101468e+10
# std     2.233310e+10
# min     5.914570e+06
# 25%     1.161268e+09
# 50%     1.673350e+10
# 75%     3.249764e+10
# max     3.509679e+11

# %%
df.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker         BTC-USD     BTC-USD     BTC-USD     BTC-USD   BTC-USD
# Date
# 2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800
# 2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200
# 2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700
# 2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600
# 2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100

# %%
df = df.reset_index()

# %%
df.head()
# Out:
# Price        Date       Close        High         Low        Open    Volume
# Ticker                BTC-USD     BTC-USD     BTC-USD     BTC-USD   BTC-USD
# 0      2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800
# 1      2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200
# 2      2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700
# 3      2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600
# 4      2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100

# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
# ...

# %%
import plotly.io as pio
pio.renderers.default = 'notebook_connected'

# %%
df.columns
# Out:
# MultiIndex([(  'Date',        ''),
#             ( 'Close', 'BTC-USD'),
#             (  'High', 'BTC-USD'),
#             (   'Low', 'BTC-USD'),
#             (  'Open', 'BTC-USD'),
#             ('Volume', 'BTC-USD')],
#            names=['Price', 'Ticker'])

# %%
data01 = df.to_csv("bitcoin.csv")

# %%
data01 = pd.read_csv("bitcoin.csv")

# %%
data01.head()
# Out:
#     Price        Date               Close                High  \
# 0  Ticker         NaN             BTC-USD             BTC-USD
# 1       0  2014-09-17   457.3340148925781  468.17401123046875
# 2       1  2014-09-18  424.44000244140625   456.8599853515625
# 3       2  2014-09-19   394.7959899902344   427.8349914550781
# 4       3  2014-09-20  408.90399169921875   423.2959899902344
#
#                   Low               Open    Volume
# 0             BTC-USD            BTC-USD   BTC-USD
# 1   452.4219970703125   465.864013671875  21056800
# 2     413.10400390625  456.8599853515625  34483200
# 3   384.5320129394531  424.1029968261719  37919700
# 4  389.88299560546875  394.6730041503906  36863600

# %%
# Candlesticks
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'],
                                    high = data01['High'],
                                    low = data01['Low'],
                                    close = data01['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = df.drop(['Date'], axis = 1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25952\1002300862.py:1: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
df.head()
# Out:
# Price        Close        High         Low        Open    Volume
# Ticker     BTC-USD     BTC-USD     BTC-USD     BTC-USD   BTC-USD
# 0       457.334015  468.174011  452.421997  465.864014  21056800
# 1       424.440002  456.859985  413.104004  456.859985  34483200
# 2       394.795990  427.834991  384.532013  424.102997  37919700
# 3       408.903992  423.295990  389.882996  394.673004  36863600
# 4       398.821014  412.425995  393.181000  408.084991  26580100

# %%
# Plot to check the closing price over time
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 2)
plt.title(f'{stock} Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.legend()
plt.show()

# %%
# Graph for Opening Prices over time
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 2)
plt.title(f'{stock} Opening Prices Over Time')
plt.legend()
plt.show()

# %%
# Graph for High Prices over time
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High Prices Over Time')
plt.legend()
plt.show()

# %%
# Graph for Low Prices over time
plt.figure(figsize=(12, 6))
plt.plot(df['Low'], label = f'{stock} Low Price', linewidth = 1)
plt.title(f'{stock} Low Prices Over Time')
plt.legend()
plt.show()

# %%
# Graph for Volume over time
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume', linewidth = 1)
plt.title(f'{stock} Volume Over Time')
plt.legend()
plt.show()

# %%
# Moving Average - Can predict next day stock predictions (average prices from previos days)
temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[1:6])/5)
# Out:
# 40.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
df01
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60
# 6  70
# 7  80
# 8  90

# %%
df01.rolling(5).mean() # Calculates the moving averages of numbers starting from the 5th value
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# Ticker        BTC-USD
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 4053    114975.878359
# 4054    114898.803750
# 4055    114821.757891
# 4056    114745.276719
# 4057    114709.968906
#
# [4058 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
ema100 = df.Close.ewm(span=100, adjust=False).mean() # Calculate the exponential moving average

# %%
ema200 = df['Close'].ewm(span=200, adjust=False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} Exp. Moving Average 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exp. Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# Training & Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (2840, 1)

# %%
data_testing.shape
# Out:
# (1218, 1)

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.9 MB 4.2 MB/s eta 0:00:02
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.00414359],
#        [0.00365546],
#        [0.00321557],
#        ...,
#        [0.31241952],
#        [0.31643624],
#        [0.30938695]])

# %%
data_training_array.shape[0]
# Out:
# 2840

# %%
x_train = [] # Independent (features)
y_train = [] # Dependent (target)

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2740, 100, 1)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %%
# Model Building
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %% [markdown]
# LSTM input -> 3D Array (batch_size, time_steps, seq_len)
# LSTM can be 2D OR 3D
# 2D -> (batch_size, units)
# 3D -> (batch_size, time_steps, units)

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2)) #20% of neural should be deactivated the first time

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# C:\tf_env\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)             ┃ Output Shape       ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ lstm (LSTM)              │ (None, 100, 50)    │     10,400 │
# ├──────────────────────────┼────────────────────┼────────────┤
# │ dropout (Dropout)        │ (None, 100, 50)    │          0 │
# ├──────────────────────────┼────────────────────┼────────────┤
# │ lstm_1 (LSTM)            │ (None, 100, 60)    │     26,640 │
# ├──────────────────────────┼────────────────────┼────────────┤
# │ dropout_1 (Dropout)      │ (None, 100, 60)    │          0 │
# ├──────────────────────────┼────────────────────┼────────────┤
# │ lstm_2 (LSTM)            │ (None, 100, 80)    │     45,120 │
# ├──────────────────────────┼────────────────────┼────────────┤
# │ dropout_2 (Dropout)      │ (None, 100, 80)    │          0 │
# ├──────────────────────────┼────────────────────┼────────────┤
# ...

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 51s 390ms/step - loss: 0.0169
# Epoch 2/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 33s 384ms/step - loss: 0.0047
# Epoch 3/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 32s 377ms/step - loss: 0.0045
# Epoch 4/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 33s 388ms/step - loss: 0.0038
# Epoch 5/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 33s 384ms/step - loss: 0.0036
# Epoch 6/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 34s 390ms/step - loss: 0.0038
# Epoch 7/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 35s 405ms/step - loss: 0.0039
# Epoch 8/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 447ms/step - loss: 0.0036
# Epoch 9/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 40s 460ms/step - loss: 0.0035
# Epoch 10/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 40s 463ms/step - loss: 0.0037
# Epoch 11/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 40s 466ms/step - loss: 0.0030
# Epoch 12/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 39s 452ms/step - loss: 0.0030
# Epoch 13/50
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 41s 474ms/step - loss: 0.0030
# Epoch 14/50
# ...

# %%
past_100_days = data_training.tail(100) # This is the raw data w/o applying the scaler

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index = True)

# %%
final_df.head()
# Out:
# Ticker       BTC-USD
# 0       42190.652344
# 1       41247.824219
# 2       41077.996094
# 3       42358.808594
# 4       42892.957031

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = [] # Independent (features)
y_test = [] # Dependent (target)

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1218, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 178ms/step

# %%
y_predicted.shape
# Out:
# (1218, 1)

# %%
scaler.scale_
# Out:
# array([9.17723794e-06])

# %%
scaler_factor = 1 / 9.17723794e-06
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('stock_dl_model.keras')
